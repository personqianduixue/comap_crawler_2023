# %%
import shutil
import pandas as pd

shutil.copyfile('./all/all1.txt', './all/all1.csv')
data = pd.read_csv('./all/all1.csv')
data.head()
# Out:
#    control_number     student1      student2      student3  \
# 0         2200002  Jiaying Yin   Yingxin Liu     Zhehan Qi
# 1         2200003   Ding Xueqi     Wang Yian    Liu Yuxuan
# 2         2200004     Li Sirui       Peng Bo  Xiao Dingwen
# 3         2200005     He Yandi    Fu Weichen     Sun Qihao
# 4         2200006  Hansheng Li  Hongx1 Zhang  Haoxuan Feng
#
#                               university                   prize  Unnamed: 6
# 0  BNU-HKBU United International College  Successful Participant         NaN
# 1  BNU-HKBU United International College  Successful Participant         NaN
# 2  BNU-HKBU United International College       Honorable Mention         NaN
# 3  BNU-HKBU United International College  Successful Participant         NaN
# 4  BNU-HKBU United International College  Successful Participant         NaN

# %%
data['university'].value_counts()
# Out:
# BNU-HKBU United International College            30
# Honorable Mention                                 3
# Wuhan University                                  2
# Jiamusi University                                2
# Successful Participant                            2
# Tianjin University                                2
# Shenzhen University                               2
# China Jiliang University                          1
# Hainan university                                 1
# Maynooth Engineering                              1
# Shanghai University                               1
# Disqualified - P                                  1
# Guizhou University                                1
# University of Science and Technology of China     1
# Lanzhou University                                1
# ChongQing University of arts and sciences         1
# China University of Geosciences (wu han)          1
# NortheastAgricultural University                  1
# ...

# %%
data['prize'].value_counts()
# Out:
# Successful Participant    31
# Honorable Mention         11
# Disqualified - P           3
# Meritorious Winner         3
# Unsuccessful - I           1
# Name: prize, dtype: int64

# %%
your_univ_result=data.loc[data['university']=='BNU-HKBU United International College']
your_univ_result
# Out:
#     control_number        student1       student2       student3  \
# 0          2200002     Jiaying Yin    Yingxin Liu      Zhehan Qi
# 1          2200003      Ding Xueqi      Wang Yian     Liu Yuxuan
# 2          2200004        Li Sirui        Peng Bo   Xiao Dingwen
# 3          2200005        He Yandi     Fu Weichen      Sun Qihao
# 4          2200006     Hansheng Li   Hongx1 Zhang   Haoxuan Feng
# 9          2200011       Xu Jiayun   Hou Huantong  Chen Bingshen
# 10         2200012        Liu Yiy1     Wu Ruibing    Yu Xiaotong
# 11         2200013       Zian Wang    Yuanx1 Peng       Teng Fei
# 12         2200014      Fan Yuchen    Zhang Yihan     Guo Wenhao
# 13         2200015       Qian Yaqi   Huang Huiran     Wu Zhuogen
# 14         2200016       Zhao Zian      Zhang Yan     Yu Haoming
# 15         2200017        Li Yifan        Fei Yue  Tang Linchuan
# 16         2200018        Zhang Le    Deng X1aoqi     Xie Suiwel
# ...

# %%
your_univ_result['prize'].value_counts()
# Out:
# Successful Participant    20
# Honorable Mention          7
# Meritorious Winner         3
# Name: prize, dtype: int64
